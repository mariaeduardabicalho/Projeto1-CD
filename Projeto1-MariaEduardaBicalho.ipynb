# %% [markdown]
# ___
# # Ciência dos Dados - PROJETO 1

# %% [markdown]
# ## Maria Eduarda Peppes Bicalho
#
# ___

# %% [markdown]
# ## Desigualde informacional no Brasil : como o acesso á diferentes fontes de informações se da no território brasileiro de 2013 a 2015?

# %% [markdown]
# ___
# ## Introdução
#
#
# ----
#
#    O acessso a diferentes fontes de informação é muito importante para a construção de uma população atenada e com pensamento crítico. O Brasil, país cuja educação já se encontra precária, possui monopólios televisionais e grande desiguldade social , pecisa se preocupar com esta questão.
#
#    Esse trabalho pretende analisar o acesso a diferentes fontes de informação no Brasil nas dieferentes situações sociais. Para isso, será analisado o PNAD 2013, 2014 e 2015 estudando as variáveis renda, condição de moradia, tv por assinatura, internet no domicílio, posse de telefone celular e acesso a internet por 3G/4G.
#
#    Tv por assinatura é um importante aspecto a ser avaliado, uma vez  que a tv está muito presente na vida do brasileiro, segundo a Pesquisa Brasileira de Mídia 2015 (PBM), realizada pela Secom (Secretaria de Comunicação da Presidência da República) 95% dos brasileiro entrevistado assistem tv e desses 79% aassiste para se informar.
#
#    É importante se analisar o acesso a internete uma vez que essa proporciona um acesso variadas informações do mundo todo. Além disso, está cada vez crescendo mais, e se tornando o meio de fonte informacional para cada vez mais pessoas.
#
#    Tendo em vista que existe uma grande desigualdade social no Brasil, pretende-se avaliar se há também uma grande discrepância no acesso a informação. Visando analisar qualidade de informação por qualidade de vida, as variáveis de informação tecnológicas serão comparadas com a renda e a condição de moradia dos indivíduos. Prentende-se avaliar se houve uma melhora na variabilidade informacional de toda a população entre 2013 e 2015,e se os avanços tecnológicos influenciaram isso, para tal, fontes de informação mais antigas e mais novas serão comparadas.
#
#   Para uma melhor avaliação, as diferentes regiões do Brasil serão análisadas entre si também relacionando com o perfil socioeconômico da região.

# %% [markdown]
# ___
# ## Análise e Resultados

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
print('Esperamos trabalhar no diretório')
print(os.getcwd())
# Out:
# Esperamos trabalhar no diretório
# C:\Users\duda\Documents\ciencia dos dados\projeto1

# %%
dados15=pd.read_csv('DOM2015.csv',sep=',')
dados14=pd.read_csv('DOM2014.csv',sep=',')
dados13=pd.read_csv('DOM2013.csv',sep=',')

# %%
#2015

# %%
dados15.UF= dados15.UF.astype('category')

dados15.V02424=dados15.V02424.astype("category") #acesso internet e feito  atraves de 3g/ 4g

dados15.V0207=dados15.V0207.astype("category") #condicao de moradia

dados15.V0220=dados15.V0220.astype('category') #tem telefone celular

dados15.V02272=dados15.V02272.astype('category') #tem tv por assinatura

dados15.V02322=dados15.V02322.astype('category') # tem acessoa a internet no domi

dados15.V4621=dados15.V4621.astype('float') # renda per capita

# %%
dados15.UF.cat.categories = (['Rondônia', 'Acre', 'Amazonas', 'Roraima', 'Pará', 'Amapá', 'Tocantins', 'Maranhão', 'Piauí', 'Ceará', 'Rio Grande do Norte', 'Paraíba', 'Pernambuco', 'Alagoas', 'Sergipe', 'Bahia', 'Minas Gerais', 'Espírito Santo', 'Rio de Janeiro', 'São Paulo', 'Paraná', 'Santa Catarina', 'Rio Grande do Sul', 'Mato Grosso do Sul', 'Mato Grosso', 'Goiás', 'Distrito Federal'])

dados15.V02424.cat.categories = (['sim', 'nao'])

dados15.V0207.cat.categories = (['Proprio- ja pago', 'Proprio- ainda pagando','alugado','cedido por empregador','cedido de outra forma','outra condicao'])

dados15.V0220.cat.categories = (['sim', 'nao'])

dados15.V02272.cat.categories = (['sim', 'nao'])

dados15.V02322.cat.categories = (['sim', 'nao'])

# %%
d15=dados15.loc[:,["UF", 'V0207','V4621','V02272','V02322','V0220','V02424']]
d15.columns=['Estados','Condicao_de_moradia','Renda','Tv_por_assinatura','Internet_no_domicilio','Celular','internet_por_3g4g']
d15=d15[d15.Renda<500000]
d15.tail()
# Out:
#                  Estados Condicao_de_moradia  Renda Tv_por_assinatura  \
# 151184  Distrito Federal             alugado  675.0               nao
# 151185  Distrito Federal             alugado  100.0               nao
# 151186  Distrito Federal    Proprio- ja pago  796.0               nao
# 151187  Distrito Federal    Proprio- ja pago  750.0               nao
# 151188  Distrito Federal    Proprio- ja pago  259.0               nao
#
#        Internet_no_domicilio Celular internet_por_3g4g
# 151184                   nao     sim               NaN
# 151185                   nao     sim               NaN
# 151186                   sim     sim               sim
# 151187                   nao     sim               NaN
# 151188                   sim     sim               sim

# %%
#2014

# %%
dados14.UF= dados14.UF.astype('category')

dados14.V02424=dados14.V02424.astype("category") #acesso internet e feito  atraves de 3g/ 4g

dados14.V0207=dados14.V0207.astype("category") #condicao de moradia

dados14.V0220=dados14.V0220.astype('category') #tem telefone celular

dados14.V02272=dados14.V02272.astype('category') #tem tv por assinatura

dados14.V02322=dados14.V02322.astype('category') # tem acessoa a internet no domi

dados14.V4621=dados14.V4621.astype('float') # renda per capita

# %%
dados14.UF.cat.categories = (['Rondônia', 'Acre', 'Amazonas', 'Roraima', 'Pará', 'Amapá', 'Tocantins', 'Maranhão', 'Piauí', 'Ceará', 'Rio Grande do Norte', 'Paraíba', 'Pernambuco', 'Alagoas', 'Sergipe', 'Bahia', 'Minas Gerais', 'Espírito Santo', 'Rio de Janeiro', 'São Paulo', 'Paraná', 'Santa Catarina', 'Rio Grande do Sul', 'Mato Grosso do Sul', 'Mato Grosso', 'Goiás', 'Distrito Federal'])

dados14.V02424.cat.categories = (['sim', 'nao'])

dados14.V0207.cat.categories = (['Proprio- ja pago', 'Proprio- ainda pagando','alugado','cedido por empregador','cedido de outra forma','outra condicao'])

dados14.V0220.cat.categories = (['sim', 'nao'])

dados14.V02272.cat.categories = (['sim', 'nao'])

dados14.V02322.cat.categories = (['sim', 'nao'])

# %%
d14=dados14.loc[:,["UF", 'V0207','V4621','V02272','V02322','V0220','V02424']]
d14.columns=['Estados','Condicao_de_moradia','Renda','Tv_por_assinatura','Internet_no_domicilio','Celular','internet_por_3g4g']
d14=d14[d14.Renda<500000]
d14.head()
# Out:
#     Estados Condicao_de_moradia   Renda Tv_por_assinatura  \
# 0  Rondônia             alugado   500.0               nao
# 1  Rondônia    Proprio- ja pago  1150.0               nao
# 2  Rondônia    Proprio- ja pago   724.0               sim
# 3  Rondônia    Proprio- ja pago  1700.0               sim
# 4  Rondônia    Proprio- ja pago   855.0               nao
#
#   Internet_no_domicilio Celular internet_por_3g4g
# 0                   nao     sim               NaN
# 1                   sim     sim               nao
# 2                   nao     nao               NaN
# 3                   sim     sim               nao
# 4                   sim     sim               nao

# %%
#2013

# %%
dados13.UF= dados13.UF.astype('category')

dados13.V02424=dados13.V02424.astype("category") #acesso internet e feito  atraves de 3g/ 4g

dados13.V0207=dados13.V0207.astype("category") #condicao de moradia

dados13.V0220=dados13.V0220.astype('category') #tem telefone celular

dados13.V02272=dados13.V02272.astype('category') #tem tv por assinatura

dados13.V02322=dados13.V02322.astype('category') # tem acessoa a internet no domi

dados13.V4621=dados13.V4621.astype('float') # renda per capita

# %%
dados13.UF.cat.categories = (['Rondônia', 'Acre', 'Amazonas', 'Roraima', 'Pará', 'Amapá', 'Tocantins', 'Maranhão', 'Piauí', 'Ceará', 'Rio Grande do Norte', 'Paraíba', 'Pernambuco', 'Alagoas', 'Sergipe', 'Bahia', 'Minas Gerais', 'Espírito Santo', 'Rio de Janeiro', 'São Paulo', 'Paraná', 'Santa Catarina', 'Rio Grande do Sul', 'Mato Grosso do Sul', 'Mato Grosso', 'Goiás', 'Distrito Federal'])

dados13.V02424.cat.categories = (['sim', 'nao'])

dados13.V0207.cat.categories = (['Proprio- ja pago', 'Proprio- ainda pagando','alugado','cedido por empregador','cedido de outra forma','outra condicao'])

dados13.V0220.cat.categories = (['sim', 'nao'])

dados13.V02272.cat.categories = (['sim', 'nao'])

dados13.V02322.cat.categories = (['sim', 'nao'])

# %%
d13=dados13.loc[:,["UF", 'V0207','V4621','V02272','V02322','V0220','V02424']]
d13.columns=['Estados','Condicao_de_moradia','Renda','Tv_por_assinatura','Internet_no_domicilio','Celular','internet_por_3g4g']
d13=d13[d13.Renda<500000]
d13.tail()
# Out:
#                  Estados Condicao_de_moradia  Renda Tv_por_assinatura  \
# 148690  Distrito Federal             alugado  516.0               nao
# 148692  Distrito Federal             alugado  800.0               nao
# 148693  Distrito Federal    Proprio- ja pago  100.0               nao
# 148694  Distrito Federal    Proprio- ja pago  387.0               sim
# 148695  Distrito Federal             alugado  400.0               nao
#
#        Internet_no_domicilio Celular internet_por_3g4g
# 148690                   nao     sim               NaN
# 148692                   nao     sim               NaN
# 148693                   sim     sim               sim
# 148694                   sim     sim               nao
# 148695                   nao     sim               NaN

# %% [markdown]
# # Relação variáveis por condição da moradia
#
# Pretende-se avaliar o acesso de diferentes grupos sociais por meio da condição de moradia à diferentes fontes de informação.

# %% [markdown]
# ### Tv por assinatura

# %%
crt5=(pd.crosstab(d15.Tv_por_assinatura,d15.Condicao_de_moradia,margins=False,rownames=['tv'], colnames=['condicao'],normalize='columns')*100).round(decimals=0)
plot = crt5.T.plot(kind='bar', stacked=True,title="Tv por assinatura por condição da moradia em 2015",figsize=(5, 5), color=("g","r"))
plot.set_ylim([0, 100])
plt.xlabel('condicao')
plt.show()

crt4=(pd.crosstab(d14.Tv_por_assinatura,d14.Condicao_de_moradia,margins=False,rownames=['tv'], colnames=['condicao'],normalize='columns')*100).round(decimals=0)
plot = crt4.T.plot(kind='bar', stacked=True,title=' Tv por assinatura por condição da moradia em 2014',figsize=(5, 5),color=("g","r"))
plot.set_ylim([0, 100])
plt.xlabel('condicao')
plt.show()

crt3=(pd.crosstab(d13.Tv_por_assinatura,d13.Condicao_de_moradia,margins=False,rownames=['tv'], colnames=['condicao'],normalize='columns')*100).round(decimals=0)
plot = crt3.T.plot(kind='bar', stacked=True,title=' Tv por assinatura por condição da moradia em 2013',figsize=(5, 5),color=("g","r"))
plot.set_ylim([0, 100])
plt.xlabel('condicao')
plt.show()

# %% [markdown]
# ###  Internet no domicílio

# %%
crt52=(pd.crosstab(d15.Internet_no_domicilio,d15.Condicao_de_moradia,margins=False,rownames=['internet'], colnames=['condicao'],normalize='columns')*100).round(decimals=0)
plot = crt52.T.plot(kind='bar', stacked=True,title='Internet no domicílio por Condição de moradia 2015',figsize=(5, 5),color=("g","r"))
plot.set_ylim([0, 100])
plt.xlabel('condicao')
plt.show()

crt42=(pd.crosstab(d14.Internet_no_domicilio,d14.Condicao_de_moradia,margins=False,rownames=['internet'], colnames=['condicao'],normalize='columns')*100).round(decimals=0)
plot = crt42.T.plot(kind='bar', stacked=True,title='Internet no domicílio por Condição de moradia 2014',figsize=(5, 5),color=("g","r"))
plot.set_ylim([0, 100])
plt.xlabel('condicao')
plt.show()

crt32=(pd.crosstab(d13.Internet_no_domicilio,d13.Condicao_de_moradia,margins=False,rownames=['internet'], colnames=['condicao'],normalize='columns')*100).round(decimals=0)
plot = crt32.T.plot(kind='bar', stacked=True,title=' Internet no domicílio por Condição de moradia 2013',figsize=(5, 5),color=("g","r"))
plot.set_ylim([0, 100])
plt.xlabel('condicao')
plt.show()

# %% [markdown]
# ### Telefone Celular

# %%
crt53=(pd.crosstab(d15.Celular,d15.Condicao_de_moradia,margins=False,rownames=['3g/4g'], colnames=['condicao'],normalize='columns')*100).round(decimals=0)
plot = crt53.T.plot(kind='bar', stacked=True,title='internet por 3G ou 4G por condição da moradia 2015',figsize=(5, 5),color=("g","r"))
plot.set_ylim([0, 100])
plt.xlabel('condicao')
plt.show()

crt43=(pd.crosstab(d14.Celular,d14.Condicao_de_moradia,margins=False,rownames=['3g/4g'], colnames=['condicao'],normalize='columns')*100).round(decimals=0)
plot = crt43.T.plot(kind='bar', stacked=True,title=' internet por 3G ou 4G por condição da moradia 2014',figsize=(5, 5),color=("g","r"))
plot.set_ylim([0, 100])
plt.xlabel('condicao')
plt.show()

crt33=(pd.crosstab(d13.Celular,d13.Condicao_de_moradia,margins=False,rownames=['3g/4g'], colnames=['condicao'],normalize='columns')*100).round(decimals=0)
plot = crt33.T.plot(kind='bar', stacked=True,title='internet por 3G ou 4G por condição da moradia 2013',figsize=(5, 5),color=("g","r"))
plot.set_ylim([0, 100])
plt.xlabel('condicao')
plt.show()

# %% [markdown]
# ###  Acesso a  internet por 3G ou 4G

# %%
crt54=(pd.crosstab(d15.internet_por_3g4g,d15.Condicao_de_moradia,margins=False,rownames=['3g/4g'], colnames=['condicao'],normalize='columns')*100).round(decimals=0)
plot = crt54.T.plot(kind='bar', stacked=True,title='internet por 3G ou 4G por condição da moradia 2015',figsize=(5, 5),color=("g","r"))
plot.set_ylim([0, 100])
plt.xlabel('condicao')
plt.show()

crt44=(pd.crosstab(d14.internet_por_3g4g,d14.Condicao_de_moradia,margins=False,rownames=['3g/4g'], colnames=['condicao'],normalize='columns')*100).round(decimals=0)
plot = crt44.T.plot(kind='bar', stacked=True,title=' internet por 3G ou 4G por condição da moradia 2014',figsize=(5, 5),color=("g","r"))
plot.set_ylim([0, 100])
plt.xlabel('condicao')
plt.show()

crt34=(pd.crosstab(d13.internet_por_3g4g,d13.Condicao_de_moradia,margins=False,rownames=['3g/4g'], colnames=['condicao'],normalize='columns')*100).round(decimals=0)
plot = crt34.T.plot(kind='bar', stacked=True,title='internet por 3G ou 4G por condição da moradia 2013',figsize=(5, 5),color=("g","r"))
plot.set_ylim([0, 100])
plt.xlabel('condicao')
plt.show()

# %% [markdown]
# ### Conclusões tiradas a partir dos gráficos "Relação variáveis por condição da moradia"
#
# Os gráficos de variáveis por condição de moradia são mais homegêneos,tendo o tipo de moradia "Proprio - ainda pagando" se destacando sempre como o que possui um maior em todas as variáveis informacionais  e o "cedido por empregador" juntamente com o "cedido de outra forma"  como os menores. Além disso os gráficos de  Internet no domicílio e Tv por assinatura possuem relações mais heterogêneas que internet por 3g e 4g e celular.

# %% [markdown]
# # Gráficos por renda

# %%
d15.Renda.value_counts().head()
d15.Renda.describe()
# Out:
# count    115626.000000
# mean       1250.046391
# std        1957.210132
# min           0.000000
# 25%         416.000000
# 50%         788.000000
# 75%        1333.000000
# max      150000.000000
# Name: Renda, dtype: float64

# %%
#k=300
#ak=500
faixa = np.arange(0,150000,500)
excat= pd.cut(d15.Renda, bins=faixa, right=False) # bins = numero 
ut15 = (excat.value_counts(sort=False, normalize=True)*100).round(decimals=1)

# %%
plt.subplot(121)
plot = d15.Renda.plot.hist(bins=faixa, title='Renda Brasil 2015',normed=True, figsize=(12, 6),color=('coral'))
plt.xlabel('renda')
plt.ylabel('densidade')
plt.xlim(0,5000)

plt.subplot(122)
plot = d15.Renda.plot(kind='box',title='renda',figsize=(12,6))
plt.ylim(0,35000)
# Out:
# (0, 35000)

# %% [markdown]
# ### Conclusões a partir dos gráficos
#
# Gráfico a cima mostram a desiguldade social existente no Brasil,com grande assimetria para direita e com impressionante quantidade de valores aberrantes.

# %% [markdown]
# # Condição de moradia por renda

# %%
d15[d15.Condicao_de_moradia == "Proprio- ja pago"].Renda.describe()
# Out:
# count     81483.000000
# mean       1235.948505
# std        1982.579610
# min           0.000000
# 25%         417.000000
# 50%         788.000000
# 75%        1300.000000
# max      150000.000000
# Name: Renda, dtype: float64

# %%
plt.subplot(141)
plot = d15.Renda[d15.Condicao_de_moradia=='Proprio- ja pago'].plot.hist(bins=faixa, title='Proprio- ja pago 2015',normed=True, figsize=(15, 5),color=('coral'))
plt.xlim(0,5000)
plt.ylim(0,0.0009)
plt.xlabel('renda ')
plt.ylabel('densidade')

plt.subplot(142)
plot = d15.Renda[d15.Condicao_de_moradia=='alugado'].plot.hist(bins=faixa, title='alugado 2015',normed=True, figsize=(15, 5),color=('coral'))
plt.xlim(0,5000)
plt.ylabel('densidade')
plt.xlabel('renda ')
plt.ylim(0,0.0009)

plt.subplot(143)
plot = d15.Renda[d15.Condicao_de_moradia=='cedido por empregador'].plot.hist(bins=faixa, title='cedido por empregador 2015',normed=True, figsize=(15, 5),color=('coral'))
plt.xlim(0,5000)
plt.ylabel('densidade')
plt.xlabel('renda')
plt.ylim(0,0.0009)

plt.subplot(144)
plot = d15.Renda[d15.Condicao_de_moradia=='outra condicao'].plot.hist(bins=faixa, title='outra condicao 2015',normed=True, figsize=(15, 5),color=('coral'))
plt.xlim(0,5000)
plt.ylabel('densidade')
plt.xlabel('renda')
plt.ylim(0,0.0009)
# Out:
# (0, 0.0009)

# %%
d15.loc[(d15.Renda <=1000), 'DivRenda']='1000'
d15.loc[(d15.Renda <=2000) & (d15.Renda > 1000) , 'DivRenda']='2000'
d15.loc[(d15.Renda <=3000) & (d15.Renda > 2000) , 'DivRenda']='3000'
d15.loc[(d15.Renda <=4000) & (d15.Renda > 3000) , 'DivRenda']='4000'
d15.loc[(d15.Renda <=5000) & (d15.Renda > 4000) , 'DivRenda']='5000'
d15.loc[(d15.Renda >5000), 'DivRenda']='> 5000'

# %%
d14.loc[(d14.Renda <=1000), 'DivRenda']='1000'
d14.loc[(d14.Renda <=2000) & (d14.Renda > 1000) , 'DivRenda']='2000'
d14.loc[(d14.Renda <=3000) & (d14.Renda > 2000) , 'DivRenda']='3000'
d14.loc[(d14.Renda <=4000) & (d14.Renda > 3000) , 'DivRenda']='4000'
d14.loc[(d14.Renda <=5000) & (d14.Renda > 4000) , 'DivRenda']='5000'
d14.loc[(d14.Renda >5000), 'DivRenda']='> 5000'

# %%
d13.loc[(d13.Renda <=1000), 'DivRenda']='1000'
d13.loc[(d13.Renda <=2000) & (d13.Renda > 1000) , 'DivRenda']='2000'
d13.loc[(d13.Renda <=3000) & (d13.Renda > 2000) , 'DivRenda']='3000'
d13.loc[(d13.Renda <=4000) & (d13.Renda > 3000) , 'DivRenda']='4000'
d13.loc[(d13.Renda <=5000) & (d13.Renda > 4000) , 'DivRenda']='5000'
d13.loc[(d13.Renda >5000), 'DivRenda']='> 5000'

# %% [markdown]
# # Condição de moradia pelas faixas de renda ( até 1000, até 2000, até 3000,até 4000, até 5000 e maor que 5000)
#
# Para visualizar melhor como rendas menores e maiores funcionam, separei em faixas com intervalos escolhidos a partir do diferença observada no gráfico por densidade relativa, podendo observar o comportamento de cada uma.

# %%
crt=(pd.crosstab(d15.Condicao_de_moradia,d15.DivRenda,margins=False,rownames=['Condição de moradia'], colnames=['renda'],normalize='columns')*100).round(decimals=0)
plot = crt.T.plot(kind='bar',color=( 'salmon',"rebeccapurple",'deepskyblue', 'yellow','deeppink','c'), stacked=True,title='2015',figsize=(5, 5))
plot.set_ylim([0, 100])
plt.xlabel('renda')
ax = plt.subplot(111)
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

crt=(pd.crosstab(d14.Condicao_de_moradia,d14.DivRenda,margins=False,rownames=['Condição de moradia'], colnames=['renda'],normalize='columns')*100).round(decimals=0)
plot = crt.T.plot(kind='bar',color=( 'salmon',"rebeccapurple",'deepskyblue', 'yellow','deeppink', 'c'), stacked=True,title='2014',figsize=(5, 5))
plot.set_ylim([0, 100])
plt.xlabel('renda')
ax = plt.subplot(111)
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

crt=(pd.crosstab(d13.Condicao_de_moradia,d13.DivRenda,margins=False,rownames=['Condição de moradia'], colnames=['renda'],normalize='columns')*100).round(decimals=0)
plot = crt.T.plot(kind='bar',color=( 'salmon',"rebeccapurple",'deepskyblue', 'yellow','deeppink', 'c'), stacked=True,title='2013',figsize=(5, 5))
plot.set_ylim([0, 100])
plt.xlabel('renda')
ax = plt.subplot(111)
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %% [markdown]
# ### Conclusões tiradas a partir dos gráficos "condição de moradia por renda"
#
# Os gráficos se mostram homogêneos em razão de em todas as faixas de renda os tipos de  moradia  se encontrarem com percentual muito similar. É importante notar que mais uma vez os tipos de moradia "Proprio-ainda pagando", "cedido por empregador" e "cedido de outa forma" se destacam. Nos gráficos a cima a condição "Proprio-ainda pagando" na renda de até 1000 reais se mostra muito menor, enquanto "cedido de outra forma" se encontra muito maior na faixa de renda mais baixa juntamente com "cedido por empregador" , o qual em 2015 não aparece nas duas faixas de renda maiores, e essas duas condições nas faixas apartir de 4000 reais,nos 3 anos, mantiveram quase insignificantes.
#
# Tendo em vista que é muito pequena a diferença da condição de moradia relacionada a renda, a curta defasagem nos gráficos de internet no domicílio, 3g/4g celular e celular por condição da moradia é explicada,tendo em vista que a amostra para cada condição de moradia contem quase a mesma quantidade percentual de pessoas de cada renda, não possibilitando uma leitura de públicos diferentes. os tipos de moradia ´que possuem percentuais maiores nas faixas de renda mais baixas, possuem percentuais menores também nos gráficos "Relação variáveis por condição da moradia", tendo a mesma relação para os que aparecem maiores nas faixas de renda mais alta.

# %% [markdown]
# # Relação variáveis por renda

# %% [markdown]
# ## Acesso a  internet por 3G ou 4G

# %%
crt=(pd.crosstab(d15.internet_por_3g4g,d15.DivRenda,margins=False,rownames=['3g/4g'], colnames=['renda'],normalize='columns')*100).round(decimals=0)
plot = crt.T.plot(kind='bar', stacked=True,title='2015',figsize=(5, 5),color=("g","r"))
plot.set_ylim([0, 100])
plt.xlabel('renda')
plt.show()

crt=(pd.crosstab(d14.internet_por_3g4g,d14.DivRenda,margins=False,rownames=['3g/4g'], colnames=['renda'],normalize='columns')*100).round(decimals=0)
plot = crt.T.plot(kind='bar', stacked=True,title='2014',figsize=(5, 5),color=("g","r"))
plot.set_ylim([0, 100])
plt.xlabel('renda')
plt.show()

crt=(pd.crosstab(d13.internet_por_3g4g,d13.DivRenda,margins=False,rownames=['3g/4g'], colnames=['renda'],normalize='columns')*100).round(decimals=0)
plot = crt.T.plot(kind='bar', stacked=True,title='2013',figsize=(5, 5),color=("g","r"))
plot.set_ylim([0, 100])
plt.xlabel('renda')
plt.show()

# %% [markdown]
# ## Telefone celular

# %%
crt=(pd.crosstab(d15.Celular,d15.DivRenda,margins=False,rownames=['celular'], colnames=['renda'],normalize='columns')*100).round(decimals=0)
plot = crt.T.plot(kind='bar', stacked=True,title='2015',figsize=(5, 5),color=("g","r"))
plot.set_ylim([0, 100])
plt.xlabel('renda')
plt.show()

crt=(pd.crosstab(d14.Celular,d14.DivRenda,margins=False,rownames=['celular'], colnames=['renda'],normalize='columns')*100).round(decimals=0)
plot = crt.T.plot(kind='bar', stacked=True,title='2014',figsize=(5, 5),color=("g","r"))
plot.set_ylim([0, 100])
plt.xlabel('renda')
plt.show()

crt=(pd.crosstab(d13.Celular,d13.DivRenda,margins=False,rownames=['celular'], colnames=['renda'],normalize='columns')*100).round(decimals=0)
plot = crt.T.plot(kind='bar', stacked=True,title='2013',figsize=(5, 5),color=("g","r"))
plot.set_ylim([0, 100])
plt.xlabel('renda')
plt.show()

# %% [markdown]
# ## internet no domicíclio

# %%
crt=(pd.crosstab(d15.Internet_no_domicilio,d15.DivRenda,margins=False,rownames=['internet'], colnames=['renda'],normalize='columns')*100).round(decimals=0)
plot = crt.T.plot(kind='bar', stacked=True,title='2015',figsize=(5, 5),color=("g","r"))
plot.set_ylim([0, 100])
plt.xlabel('renda')
plt.show()

crt=(pd.crosstab(d14.Internet_no_domicilio,d14.DivRenda,margins=False,rownames=['internet'], colnames=['renda'],normalize='columns')*100).round(decimals=0)
plot = crt.T.plot(kind='bar', stacked=True,title='2014',figsize=(5, 5),color=("g","r"))
plot.set_ylim([0, 100])
plt.xlabel('renda')
plt.show()

crt=(pd.crosstab(d13.Internet_no_domicilio,d13.DivRenda,margins=False,rownames=['internet'], colnames=['renda'],normalize='columns')*100).round(decimals=0)
plot = crt.T.plot(kind='bar', stacked=True,title='2013',figsize=(5, 5),color=("g","r"))
plot.set_ylim([0, 100])
plt.xlabel('renda')
plt.show()

# %% [markdown]
# ## Tv por assinatura

# %%
#tv por assinatura
crt=(pd.crosstab(d15.Tv_por_assinatura,d15.DivRenda,margins=False,rownames=['tv por assinatura'], colnames=['renda'],normalize='columns')*100).round(decimals=0)
plot = crt.T.plot(kind='bar', stacked=True,title='2015',figsize=(5, 5),color=("g","r"))
plot.set_ylim([0, 100])
plt.xlabel('renda')
plt.show()

crt=(pd.crosstab(d14.Tv_por_assinatura,d14.DivRenda,margins=False,rownames=['tv por assinatura'], colnames=['renda'],normalize='columns')*100).round(decimals=0)
plot = crt.T.plot(kind='bar', stacked=True,title='2014',figsize=(5, 5),color=("g","r"))
plot.set_ylim([0, 100])
plt.xlabel('renda')
plt.show()

crt=(pd.crosstab(d13.Tv_por_assinatura,d13.DivRenda,margins=False,rownames=['tv por assinatura'], colnames=['renda'],normalize='columns')*100).round(decimals=0)
plot = crt.T.plot(kind='bar', stacked=True,title='2013',figsize=(5, 5),color=("g","r"))
plot.set_ylim([0, 100])
plt.xlabel('renda')
plt.show()

# %% [markdown]
# ### Conclusões tiradas a partir dos gráficos "variáveis por renda"
#
# É possível perceber que internet no domicílio e tv por assinatura se possuem maiores discrepâncias entre as diferentes rendas, enquanto celular e acesso a internet por 3G/4G se mostram mais homogêneos.

# %% [markdown]
# # Comparação percentual entre 2013, 2014 e 2015

# %%
ut5 = (d15.Tv_por_assinatura.value_counts(sort=False, normalize=True)*100).round(decimals=1)
ut4 = (d14.Tv_por_assinatura.value_counts(sort=False, normalize=True)*100).round(decimals=1)
ut3 = (d13.Tv_por_assinatura.value_counts(sort=False, normalize=True)*100).round(decimals=1)

ut51 = (d15.internet_por_3g4g.value_counts(sort=False, normalize=True)*100).round(decimals=1)
ut41 = (d14.internet_por_3g4g.value_counts(sort=False, normalize=True)*100).round(decimals=1)
ut31 = (d13.internet_por_3g4g.value_counts(sort=False, normalize=True)*100).round(decimals=1)

ut52 = (d15.Celular.value_counts(sort=False, normalize=True)*100).round(decimals=1)
ut42 = (d14.Celular.value_counts(sort=False, normalize=True)*100).round(decimals=1)
ut32 = (d13.Celular.value_counts(sort=False, normalize=True)*100).round(decimals=1)

ut53 = (d15.Internet_no_domicilio.value_counts(sort=False, normalize=True)*100).round(decimals=1)
ut43 = (d14.Internet_no_domicilio.value_counts(sort=False, normalize=True)*100).round(decimals=1)
ut33 = (d13.Internet_no_domicilio.value_counts(sort=False, normalize=True)*100).round(decimals=1)

# %%
# tv

fig = plt.figure(figsize=(15, 5))# tamanho= figsize
plt.subplot(131) #quantas linhas quantas colunas e qual a posicao dos 3 graficos/ onde os graficos seram plotadaos
plot = ut3.plot(kind='pie',title='2013',autopct='%.1f')

plt.subplot(132)
plot = ut4.plot(kind='pie',title='2014',autopct='%.1f')

plt.subplot(133)
plot = ut5.plot(kind='pie',title='2015',autopct='%.1f')

plt.tight_layout()
plt.show()

# 3g
fig = plt.figure(figsize=(15, 5))# tamanho= figsize
plt.subplot(131) #quantas linhas quantas colunas e qual a posicao dos 3 graficos/ onde os graficos seram plotadaos
plot = ut31.plot(kind='pie',title='2013',autopct='%.1f')

plt.subplot(132)
plot = ut41.plot(kind='pie',title='2014',autopct='%.1f')

plt.subplot(133)
plot = ut51.plot(kind='pie',title='2015',autopct='%.1f')

plt.tight_layout()
plt.show()

# celular
#colors=['g','r']
fig = plt.figure(figsize=(15, 5))# tamanho= figsize
plt.subplot(131) #quantas linhas quantas colunas e qual a posicao dos 3 graficos/ onde os graficos seram plotadaos
plot = ut32.plot(kind='pie',title='2013',autopct='%.1f')

plt.subplot(132)
plot = ut42.plot(kind='pie',title='2014',autopct='%.1f')

plt.subplot(133)
plot = ut52.plot(kind='pie',title='2015',autopct='%.1f')

plt.tight_layout()
plt.show()

#internet em casa 

fig = plt.figure(figsize=(15, 5))# tamanho= figsize
plt.subplot(131) #quantas linhas quantas colunas e qual a posicao dos 3 graficos/ onde os graficos seram plotadaos
plot = ut33.plot(kind='pie',title='2013',autopct='%.1f')

plt.subplot(132)
plot = ut43.plot(kind='pie',title='2014',autopct='%.1f')

plt.subplot(133)
plot = ut53.plot(kind='pie',title='2015',autopct='%.1f')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Conclusões tiradas a partir dos gráficos "Comparação percentual entre 2013, 2014 e 2015"
#
# Percebe-se que o acesso a internet móvel foi o que mais expandiu ao longo dos 3 anos, crescendo quase 30%, seguido pela inernet no domicío que cresceu 10 %, enquanto a tv por assinatura não chegou a crescer 3% e a posse de etelefone celular se manteve a cima dos 90%.  É importante frisar que o crescimento do acesso a internet por 3G/4G se mostra ainda mais significativo quando  tem-se em vista o alcance do celular no território brasileiro.

# %% [markdown]
# # Comparação percentual entre as regiões brasileiras

# %%
d15.loc[(d15.Estados=='Rondônia')|(d15.Estados=='Rondônia')|(d15.Estados=='Amazonas')|(d15.Estados=='Roraima')|(d15.Estados=='Pará')|(d15.Estados=='Amapá')|(d15.Estados=='Tocantins'), 'REGIAO']='Norte'
d15.loc[(d15.Estados=='Maranhão')|(d15.Estados=='Piauí')|(d15.Estados=='Ceará')|(d15.Estados=='Rio Grande do Norte')|(d15.Estados=='Paraíba')|(d15.Estados=='Pernambuco')|(d15.Estados=='Alagoas')|(d15.Estados=='Sergipe')|(d15.Estados=='Bahia'), 'REGIAO']='Nordeste'
d15.loc[(d15.Estados== 'Minas Gerais')|(d15.Estados=='Espírito Santo')|(d15.Estados=='Rio de Janeiro')|(d15.Estados=='São Paulo'), 'REGIAO']='Sudeste'
d15.loc[(d15.Estados=='Paraná')|(d15.Estados=='Santa Catarina')|(d15.Estados=='Rio Grande do Sul'), 'REGIAO']='Sul'
d15.loc[(d15.Estados=='Mato Grosso do Sul')|(d15.Estados=='Mato Grosso')|(d15.Estados=='Goiás')|(d15.Estados=='Distrito Federal'), 'REGIAO']='Centro-Oeste'


d14.loc[(d14.Estados=='Rondônia')|(d14.Estados=='Rondônia')|(d14.Estados=='Amazonas')|(d14.Estados=='Roraima')|(d14.Estados=='Pará')|(d14.Estados=='Amapá')|(d14.Estados=='Tocantins'), 'REGIAO']='Norte'
d14.loc[(d14.Estados=='Maranhão')|(d14.Estados=='Piauí')|(d14.Estados=='Ceará')|(d14.Estados=='Rio Grande do Norte')|(d14.Estados=='Paraíba')|(d14.Estados=='Pernambuco')|(d14.Estados=='Alagoas')|(d14.Estados=='Sergipe')|(d14.Estados=='Bahia'), 'REGIAO']='Nordeste'
d14.loc[(d14.Estados== 'Minas Gerais')|(d14.Estados=='Espírito Santo')|(d14.Estados=='Rio de Janeiro')|(d14.Estados=='São Paulo'), 'REGIAO']='Sudeste'
d14.loc[(d14.Estados=='Paraná')|(d14.Estados=='Santa Catarina')|(d14.Estados=='Rio Grande do Sul'), 'REGIAO']='Sul'
d14.loc[(d14.Estados=='Mato Grosso do Sul')|(d14.Estados=='Mato Grosso')|(d14.Estados=='Goiás')|(d14.Estados=='Distrito Federal'), 'REGIAO']='Centro-Oeste'

d13.loc[(d13.Estados=='Rondônia')|(d13.Estados=='Rondônia')|(d13.Estados=='Amazonas')|(d13.Estados=='Roraima')|(d13.Estados=='Pará')|(d13.Estados=='Amapá')|(d13.Estados=='Tocantins'), 'REGIAO']='Norte'
d13.loc[(d13.Estados=='Maranhão')|(d13.Estados=='Piauí')|(d13.Estados=='Ceará')|(d13.Estados=='Rio Grande do Norte')|(d13.Estados=='Paraíba')|(d13.Estados=='Pernambuco')|(d13.Estados=='Alagoas')|(d13.Estados=='Sergipe')|(d13.Estados=='Bahia'), 'REGIAO']='Nordeste'
d13.loc[(d13.Estados== 'Minas Gerais')|(d13.Estados=='Espírito Santo')|(d13.Estados=='Rio de Janeiro')|(d13.Estados=='São Paulo'), 'REGIAO']='Sudeste'
d13.loc[(d13.Estados=='Paraná')|(d13.Estados=='Santa Catarina')|(d13.Estados=='Rio Grande do Sul'), 'REGIAO']='Sul'
d13.loc[(d13.Estados=='Mato Grosso do Sul')|(d13.Estados=='Mato Grosso')|(d13.Estados=='Goiás')|(d13.Estados=='Distrito Federal'), 'REGIAO']='Centro-Oeste'

# %%
sd15=d15[d15.REGIAO=='Sudeste'] 
sd14=d14[d14.REGIAO=='Sudeste']
sd13=d13[d13.REGIAO=='Sudeste']

n15=d15[d15.REGIAO=='Norte'] 
n14=d14[d14.REGIAO=='Norte']
n13=d13[d13.REGIAO=='Norte']

ne15=d15[d15.REGIAO=='Nordeste'] 
ne14=d14[d14.REGIAO=='Nordeste']
ne13=d13[d13.REGIAO=='Nordeste']

s15=d15[d15.REGIAO=='Sul'] 
s14=d14[d14.REGIAO=='Sul']
s13=d13[d13.REGIAO=='Sul']

c15=d15[d15.REGIAO=="Centro-Oeste"] 
c14=d14[d14.REGIAO=="Centro-Oeste"]
c13=d13[d13.REGIAO=="Centro-Oeste"]

# %%
n5 = (n15.Tv_por_assinatura.value_counts(sort=False, normalize=True)*100).round(decimals=1)
n4 = (n14.Tv_por_assinatura.value_counts(sort=False, normalize=True)*100).round(decimals=1)
n3 = (n13.Tv_por_assinatura.value_counts(sort=False, normalize=True)*100).round(decimals=1)

n51 = (n15.internet_por_3g4g.value_counts(sort=False, normalize=True)*100).round(decimals=1)
n41 = (n14.internet_por_3g4g.value_counts(sort=False, normalize=True)*100).round(decimals=1)
n31 = (n13.internet_por_3g4g.value_counts(sort=False, normalize=True)*100).round(decimals=1)

n52 = (n15.Celular.value_counts(sort=False, normalize=True)*100).round(decimals=1)
n42 = (n14.Celular.value_counts(sort=False, normalize=True)*100).round(decimals=1)
n32 = (n13.Celular.value_counts(sort=False, normalize=True)*100).round(decimals=1)

ne5 = (ne15.Tv_por_assinatura.value_counts(sort=False, normalize=True)*100).round(decimals=1)
ne4 = (ne14.Tv_por_assinatura.value_counts(sort=False, normalize=True)*100).round(decimals=1)
ne3 = (ne13.Tv_por_assinatura.value_counts(sort=False, normalize=True)*100).round(decimals=1)

ne51 = (ne15.internet_por_3g4g.value_counts(sort=False, normalize=True)*100).round(decimals=1)
ne41 = (ne14.internet_por_3g4g.value_counts(sort=False, normalize=True)*100).round(decimals=1)
ne31 = (ne13.internet_por_3g4g.value_counts(sort=False, normalize=True)*100).round(decimals=1)

ne52 = (ne15.Celular.value_counts(sort=False, normalize=True)*100).round(decimals=1)
ne42 = (ne14.Celular.value_counts(sort=False, normalize=True)*100).round(decimals=1)
ne32 = (ne13.Celular.value_counts(sort=False, normalize=True)*100).round(decimals=1)

s5 = (s15.Tv_por_assinatura.value_counts(sort=False, normalize=True)*100).round(decimals=1)
s4 = (s14.Tv_por_assinatura.value_counts(sort=False, normalize=True)*100).round(decimals=1)
s3 = (s13.Tv_por_assinatura.value_counts(sort=False, normalize=True)*100).round(decimals=1)

s51 = (s15.internet_por_3g4g.value_counts(sort=False, normalize=True)*100).round(decimals=1)
s41 = (s14.internet_por_3g4g.value_counts(sort=False, normalize=True)*100).round(decimals=1)
s31 = (s13.internet_por_3g4g.value_counts(sort=False, normalize=True)*100).round(decimals=1)

s52 = (s15.Celular.value_counts(sort=False, normalize=True)*100).round(decimals=1)
s42 = (s14.Celular.value_counts(sort=False, normalize=True)*100).round(decimals=1)
s32 = (s13.Celular.value_counts(sort=False, normalize=True)*100).round(decimals=1)

sd5 = (sd15.Tv_por_assinatura.value_counts(sort=False, normalize=True)*100).round(decimals=1)
sd4 = (sd14.Tv_por_assinatura.value_counts(sort=False, normalize=True)*100).round(decimals=1)
sd3 = (sd13.Tv_por_assinatura.value_counts(sort=False, normalize=True)*100).round(decimals=1)

sd51 = (sd15.internet_por_3g4g.value_counts(sort=False, normalize=True)*100).round(decimals=1)
sd41 = (sd14.internet_por_3g4g.value_counts(sort=False, normalize=True)*100).round(decimals=1)
sd31 = (sd13.internet_por_3g4g.value_counts(sort=False, normalize=True)*100).round(decimals=1)

sd52 = (sd15.Celular.value_counts(sort=False, normalize=True)*100).round(decimals=1)
sd42 = (sd14.Celular.value_counts(sort=False, normalize=True)*100).round(decimals=1)
sd32 = (sd13.Celular.value_counts(sort=False, normalize=True)*100).round(decimals=1)

c5 = (c15.Tv_por_assinatura.value_counts(sort=False, normalize=True)*100).round(decimals=1)
c4 = (c14.Tv_por_assinatura.value_counts(sort=False, normalize=True)*100).round(decimals=1)
c3 = (c13.Tv_por_assinatura.value_counts(sort=False, normalize=True)*100).round(decimals=1)

c51 = (c15.internet_por_3g4g.value_counts(sort=False, normalize=True)*100).round(decimals=1)
c41 = (c14.internet_por_3g4g.value_counts(sort=False, normalize=True)*100).round(decimals=1)
c31 = (c13.internet_por_3g4g.value_counts(sort=False, normalize=True)*100).round(decimals=1)

c52 = (c15.Celular.value_counts(sort=False, normalize=True)*100).round(decimals=1)
c42 = (c14.Celular.value_counts(sort=False, normalize=True)*100).round(decimals=1)
c32 = (c13.Celular.value_counts(sort=False, normalize=True)*100).round(decimals=1)

# %% [markdown]
# ### Tv por assinatura

# %%
#norte
fig = plt.figure(figsize=(15, 5))# tamanho= figsize
plt.subplot(131) #quantas linhas quantas colunas e qual a posicao dos 3 graficos/ onde os graficos seram plotadaos
plot = n3.plot(kind='pie',title='Norte 2013',autopct='%.1f')

plt.subplot(132)
plot = n4.plot(kind='pie',title='Norte 2014',autopct='%.1f')

plt.subplot(133)
plot = n5.plot(kind='pie',title='Norte 2015',autopct='%.1f')

plt.tight_layout()
plt.show()

#nordeste
fig = plt.figure(figsize=(15, 5))# tamanho= figsize
plt.subplot(131) #quantas linhas quantas colunas e qual a posicao dos 3 graficos/ onde os graficos seram plotadaos
plot = ne3.plot(kind='pie',title='Nordeste 2013',autopct='%.1f')

plt.subplot(132)
plot = ne4.plot(kind='pie',title='Nordeste 2014',autopct='%.1f')

plt.subplot(133)
plot = ne5.plot(kind='pie',title='Nordeste 2015',autopct='%.1f')

plt.tight_layout()
plt.show()

#sudeste

fig = plt.figure(figsize=(15, 5))# tamanho= figsize
plt.subplot(131) #quantas linhas quantas colunas e qual a posicao dos 3 graficos/ onde os graficos seram plotadaos
plot = sd3.plot(kind='pie',title='sudeste 2013',autopct='%.1f')

plt.subplot(132)
plot = sd4.plot(kind='pie',title='sudeste 2014',autopct='%.1f')

plt.subplot(133)
plot = sd5.plot(kind='pie',title='sudeste 2015',autopct='%.1f')

plt.tight_layout()
plt.show()


#sul
fig = plt.figure(figsize=(15, 5))# tamanho= figsize
plt.subplot(131) #quantas linhas quantas colunas e qual a posicao dos 3 graficos/ onde os graficos seram plotadaos
plot = s3.plot(kind='pie',title='Sul2013',autopct='%.1f')

plt.subplot(132)
plot = s4.plot(kind='pie',title='Sul2014',autopct='%.1f')

plt.subplot(133)
plot = s5.plot(kind='pie',title='Sul 2015',autopct='%.1f')

plt.tight_layout()
plt.show()

#centro
fig = plt.figure(figsize=(15, 5))# tamanho= figsize
plt.subplot(131) #quantas linhas quantas colunas e qual a posicao dos 3 graficos/ onde os graficos seram plotadaos
plot = c3.plot(kind='pie',title='centro-oeste 2013',autopct='%.1f')

plt.subplot(132)
plot = c4.plot(kind='pie',title='centro-oeste 2014',autopct='%.1f')

plt.subplot(133)
plot = c5.plot(kind='pie',title='centro-oeste 2015',autopct='%.1f')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### CELULAR

# %%
# norte
fig = plt.figure(figsize=(15, 5))# tamanho= figsize
plt.subplot(131) #quantas linhas quantas colunas e qual a posicao dos 3 graficos/ onde os graficos seram plotadaos
plot = n32.plot(kind='pie',title=' Norte 2013',autopct='%.1f')

plt.subplot(132)
plot = n42.plot(kind='pie',title=' Norte 2014',autopct='%.1f')

plt.subplot(133)
plot = n52.plot(kind='pie',title='Norte 2015',autopct='%.1f')

plt.tight_layout()
plt.show()

# nordeste
fig = plt.figure(figsize=(15, 5))# tamanho= figsize
plt.subplot(131) #quantas linhas quantas colunas e qual a posicao dos 3 graficos/ onde os graficos seram plotadaos
plot = ne32.plot(kind='pie',title=' Nordeste 2013',autopct='%.1f')

plt.subplot(132)
plot = ne42.plot(kind='pie',title=' Nordeste 2014',autopct='%.1f')

plt.subplot(133)
plot = ne52.plot(kind='pie',title='Nordeste 2015',autopct='%.1f')

plt.tight_layout()
plt.show()


#sudeste

fig = plt.figure(figsize=(15, 5))# tamanho= figsize
plt.subplot(131) #quantas linhas quantas colunas e qual a posicao dos 3 graficos/ onde os graficos seram plotadaos
plot = sd32.plot(kind='pie',title=' Sudeste 2013',autopct='%.1f')

plt.subplot(132)
plot = sd42.plot(kind='pie',title=' Sudeste 2014',autopct='%.1f')

plt.subplot(133)
plot = sd52.plot(kind='pie',title='Sudeste 2015',autopct='%.1f')

plt.tight_layout()
plt.show()

#sul
fig = plt.figure(figsize=(15, 5))# tamanho= figsize
plt.subplot(131) #quantas linhas quantas colunas e qual a posicao dos 3 graficos/ onde os graficos seram plotadaos
plot = s32.plot(kind='pie',title='Sul 2013',autopct='%.1f')

plt.subplot(132)
plot = s42.plot(kind='pie',title=' Sul 2014',autopct='%.1f')

plt.subplot(133)
plot = s52.plot(kind='pie',title='Sul 2015',autopct='%.1f')

plt.tight_layout()
plt.show()

#centro
fig = plt.figure(figsize=(15, 5))# tamanho= figsize
plt.subplot(131) #quantas linhas quantas colunas e qual a posicao dos 3 graficos/ onde os graficos seram plotadaos
plot = c32.plot(kind='pie',title='centro-oeste 2013',autopct='%.1f')

plt.subplot(132)
plot = c42.plot(kind='pie',title=' centro-oeste 2014',autopct='%.1f')

plt.subplot(133)
plot = c52.plot(kind='pie',title="centro-oeste 2015",autopct='%.1f')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Acesso a internet por 3G/4G

# %%
# norte
fig = plt.figure(figsize=(15, 5))# tamanho= figsize
plt.subplot(131) #quantas linhas quantas colunas e qual a posicao dos 3 graficos/ onde os graficos seram plotadaos
plot = n31.plot(kind='pie',title=' Norte 2013',autopct='%.1f')

plt.subplot(132)
plot = n41.plot(kind='pie',title=' Norte 2014',autopct='%.1f')

plt.subplot(133)
plot = n51.plot(kind='pie',title='Norte 2015',autopct='%.1f')

plt.tight_layout()
plt.show()

# nordeste
fig = plt.figure(figsize=(15, 5))# tamanho= figsize
plt.subplot(131) #quantas linhas quantas colunas e qual a posicao dos 3 graficos/ onde os graficos seram plotadaos
plot = ne31.plot(kind='pie',title=' Nordeste 2013',autopct='%.1f')

plt.subplot(132)
plot = ne41.plot(kind='pie',title=' Nordeste 2014',autopct='%.1f')

plt.subplot(133)
plot = ne51.plot(kind='pie',title='Nordeste 2015',autopct='%.1f')

plt.tight_layout()
plt.show()

#sudeste

fig = plt.figure(figsize=(15, 5))# tamanho= figsize
plt.subplot(131) #quantas linhas quantas colunas e qual a posicao dos 3 graficos/ onde os graficos seram plotadaos
plot = sd31.plot(kind='pie',title=' Sudeste 2013',autopct='%.1f')

plt.subplot(132)
plot = sd41.plot(kind='pie',title=' Sudeste 2014',autopct='%.1f')

plt.subplot(133)
plot = sd51.plot(kind='pie',title='Sudeste 2015',autopct='%.1f')

plt.tight_layout()
plt.show()

#sul
fig = plt.figure(figsize=(15, 5))# tamanho= figsize
plt.subplot(131) #quantas linhas quantas colunas e qual a posicao dos 3 graficos/ onde os graficos seram plotadaos
plot = s31.plot(kind='pie',title='Sul 2013',autopct='%.1f')

plt.subplot(132)
plot = s41.plot(kind='pie',title=' Sul 2014',autopct='%.1f')

plt.subplot(133)
plot = s51.plot(kind='pie',title='Sul 2015',autopct='%.1f')

plt.tight_layout()
plt.show()

#centro
fig = plt.figure(figsize=(15, 5))# tamanho= figsize
plt.subplot(131) #quantas linhas quantas colunas e qual a posicao dos 3 graficos/ onde os graficos seram plotadaos
plot = c31.plot(kind='pie',title='centro-oeste 2013',autopct='%.1f')

plt.subplot(132)
plot = c41.plot(kind='pie',title=' centro-oeste 2014',autopct='%.1f')

plt.subplot(133)
plot = c51.plot(kind='pie',title='centro-oeste 2015',autopct='%.1f')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Conclusões tiradas a partir dos gráficos "Comparação percentual entre as regiões brasileiras"
#
# A comparação dos estados ao longo dos 3 anos pelas variaveis leva a conclusão de que houve um crescimento muito grande em todas as regiões  no uso internet por meio de 3G/4G e de que a relação dessa variável e entre os estados e ado telefone celular é homogênea, sendo ainda importante destacar que a região que possui o maior percentual de uso do 3G/4G é o norte, cujos estados estão entre os mais pobres do Brasil. Enquanto isso, a tv por assinatura e a internet no domicílio se mateve estagnada e ainda com uma hetereogeneidade entre as regiões, estando mais presente nas áreas mais desenvolvidas - sudeste, centro-oeste e sul- com percentuais parecidos e maiores que os do norte e nordeste.

# %% [markdown]
# ## Conclusão

# %% [markdown]
# A partir da análise dos resultados obtidos a cima  chega-se a conclusão de que de 2013 para 2015 houve um avanço no acesso da população brasileira a diferentes fontes de informação, e isso se deve ao acesso da população à internet móvel. Ao longo dos 3 anos, enquanto tv por assinatura e internet no domicilio cresceram de forma insuficiente, o uso da internet por 3G/4G cresceu em quase 30 porcento. Além disso, as duas variáveis com minímo desdobramento, possuem grande disparidade entre as rendas, ao passo que a de acesso a internet móvel possui pouca diferença entre os niveis sociais, juntamente com o telefone celular que está presente em mais de 90% da população. Dessa forma, o aparelho celular com internet 3G/4G representou um grande avanço na qualidade informacional do braileiro como um todo e um importante ator para o combate à desigualdade informacional no país.
